# %% [markdown]
# # Exercise 1

# %%
def get_gc_content(sequence: str): #parameters must be typed
    return 100 * (sequence.count('G') + sequence.count('C')) / len(sequence)

# %%
gc_agent = Agent(MODEL, tools=[get_gc_content])
result = gc_agent.run_sync(f"what is the gc content of the sequence {dna_sequence}?")
pretty_print_trace(result)

# %% [markdown]
# # Exercise 2

# %%
# Exercise 2 - Create an agent that uses the get_csv_stats tool to answer questions about the experiment CSV files
csv_agent = Agent(MODEL, tools=[get_csv_stats], system_prompt="You have access to experiment_1.csv and experiment_2.csv")
